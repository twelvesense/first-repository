# %% [markdown]
# <a href="https://colab.research.google.com/github/twelvesense/first-repository/blob/master/ExplNode05_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **프로젝트: 가위바위보 분류기를 만들자**

# %% [markdown]
# # 1 데이터 준비

# %% [markdown]
# ## 1-1. 필요한 라이브러리 불러오기

# %%
import warnings
warnings.filterwarnings("ignore")
import os
from PIL import Image
import glob
import numpy as np
from os.path import join
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
# !rm -r /content/test
# !rm -r /content/train

# %% [markdown]
# ## 1-2. 가위바위보 이미지 파일 *download하기*

# %%
# !mkdir -p /content/train/rock
# !mkdir -p /content/train/paper
# !mkdir -p /content/train/scissor
# !mkdir -p /content/test/rock
# !mkdir -p /content/test/paper
# !mkdir -p /content/test/scissor
# !wget -O /content/train/rock/rock.zip https://raw.githubusercontent.com/twelvesense/first-repository/master/data/rock_scissor_paper/rock.zip
# !wget -O /content/train/paper/paper.zip https://raw.githubusercontent.com/twelvesense/first-repository/master/data/rock_scissor_paper/paper.zip
# !wget -O /content/train/scissor/scissor.zip https://raw.githubusercontent.com/twelvesense/first-repository/master/data/rock_scissor_paper/scissor.zip
# !wget -O /content/test/rock/rock.zip https://raw.githubusercontent.com/twelvesense/first-repository/master/data/rock_scissor_paper/test_rock.zip
# !wget -O /content/test/paper/paper.zip https://raw.githubusercontent.com/twelvesense/first-repository/master/data/rock_scissor_paper/test_paper.zip
# !wget -O /content/test/scissor/scissor.zip https://raw.githubusercontent.com/twelvesense/first-repository/master/data/rock_scissor_paper/test_scissor.zip
# !unzip /content/train/paper/paper.zip -d /content/train/paper
# !unzip /content/train/rock/rock.zip -d /content/train/rock
# !unzip /content/train/scissor/scissor.zip -d /content/train/scissor
# !unzip /content/test/paper/paper.zip -d /content/test/paper
# !unzip /content/test/rock/rock.zip -d /content/test/rock
# !unzip /content/test/scissor/scissor.zip -d /content/test/scissor
# Out:
# --2022-05-17 23:07:50--  https://raw.githubusercontent.com/twelvesense/first-repository/master/data/rock_scissor_paper/rock.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1091596 (1.0M) [application/zip]
# Saving to: ‘/content/train/rock/rock.zip’
#
# /content/train/rock 100%[===================>]   1.04M  --.-KB/s    in 0.08s
#
# 2022-05-17 23:07:50 (12.7 MB/s) - ‘/content/train/rock/rock.zip’ saved [1091596/1091596]
#
# --2022-05-17 23:07:50--  https://raw.githubusercontent.com/twelvesense/first-repository/master/data/rock_scissor_paper/paper.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1157844 (1.1M) [application/zip]
# Saving to: ‘/content/train/paper/paper.zip’
#
# /content/train/pape 100%[===================>]   1.10M  --.-KB/s    in 0.08s
#
# 2022-05-17 23:07:50 (13.4 MB/s) - ‘/content/train/paper/paper.zip’ saved [1157844/1157844]
#
# --2022-05-17 23:07:50--  https://raw.githubusercontent.com/twelvesense/first-repository/master/data/rock_scissor_paper/scissor.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 997130 (974K) [application/zip]
# Saving to: ‘/content/train/scissor/scissor.zip’
#
# /content/train/scis 100%[===================>] 973.76K  --.-KB/s    in 0.08s
#
# 2022-05-17 23:07:50 (11.6 MB/s) - ‘/content/train/scissor/scissor.zip’ saved [997130/997130]
#
# --2022-05-17 23:07:51--  https://raw.githubusercontent.com/twelvesense/first-repository/master/data/rock_scissor_paper/test_rock.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 999146 (976K) [application/zip]
# Saving to: ‘/content/test/rock/rock.zip’
#
# /content/test/rock/ 100%[===================>] 975.73K  --.-KB/s    in 0.07s
#
# 2022-05-17 23:07:51 (12.8 MB/s) - ‘/content/test/rock/rock.zip’ saved [999146/999146]
#
# --2022-05-17 23:07:51--  https://raw.githubusercontent.com/twelvesense/first-repository/master/data/rock_scissor_paper/test_paper.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1018636 (995K) [application/zip]
# Saving to: ‘/content/test/paper/paper.zip’
#
# /content/test/paper 100%[===================>] 994.76K  --.-KB/s    in 0.06s
#
# 2022-05-17 23:07:51 (16.1 MB/s) - ‘/content/test/paper/paper.zip’ saved [1018636/1018636]
#
# --2022-05-17 23:07:51--  https://raw.githubusercontent.com/twelvesense/first-repository/master/data/rock_scissor_paper/test_scissor.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length:
#   inflating: /content/test/scissor/97.jpg
#   inflating: /content/test/scissor/98.jpg
#   inflating: /content/test/scissor/99.jpg

# %% [markdown]
# ## 1-3. 이미지 크기 조절하기 (224x224에서 28x28로)

# %%
def resize_images(img_path):
	images=glob.glob(img_path + "/*.jpg")
	print(len(images), " images to be resized.")
	target_size=(28,28)
	for img in images:
		old_img=Image.open(img)
		new_img=old_img.resize(target_size,Image.ANTIALIAS)
		new_img.save(img, "JPEG")
	print(len(images), " images resized.")
 
image_dir_path = "/content/train/scissor"
resize_images(image_dir_path)
print("가위 이미지 resize 완료!")
image_dir_path = "/content/train/rock"
resize_images(image_dir_path)
print("바위 이미지 resize 완료!")
image_dir_path = "/content/train/paper"
resize_images(image_dir_path)
print("보 이미지 resize 완료!")
image_dir_path = "/content/test/scissor"
resize_images(image_dir_path)
print("가위 이미지 resize 완료!")
image_dir_path = "/content/test/rock"
resize_images(image_dir_path)
print("바위 이미지 resize 완료!")
image_dir_path = "/content/test/paper"
resize_images(image_dir_path)
print("보 이미지 resize 완료!")
# Out:
# 100  images to be resized.
# 100  images resized.
# 가위 이미지 resize 완료!
# 100  images to be resized.
# 100  images resized.
# 바위 이미지 resize 완료!
# 100  images to be resized.
# 100  images resized.
# 보 이미지 resize 완료!
# 100  images to be resized.
# 100  images resized.
# 가위 이미지 resize 완료!
# 100  images to be resized.
# 100  images resized.
# 바위 이미지 resize 완료!
# 100  images to be resized.
# 100  images resized.
# 보 이미지 resize 완료!

# %% [markdown]
# ## 1-4. train dataset과 test dataset 준비하기

# %%
def load_data(img_path, number_of_data=300):  # 가위바위보 이미지 개수 총합
    # 가위 : 0, 바위 : 1, 보 : 2
    img_size=28
    color=3
    #이미지 데이터와 라벨(가위 : 0, 바위 : 1, 보 : 2) 데이터를 담을 행렬(matrix) 영역을 생성
    imgs=np.zeros(number_of_data*img_size*img_size*color,dtype=np.int32).reshape(number_of_data,img_size,img_size,color)
    labels=np.zeros(number_of_data,dtype=np.int32)

    idx=0
    for file in glob.iglob(img_path+'/scissor/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=0   # 가위 : 0
        idx=idx+1

    for file in glob.iglob(img_path+'/rock/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=1   # 바위 : 1
        idx=idx+1  
    
    for file in glob.iglob(img_path+'/paper/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=2   # 보 : 2
        idx=idx+1
        
    print("데이터(x_train)의 이미지 개수는", idx,"입니다.")
    return imgs, labels

# train dataset
print('학습data: ')
image_dir_path = "/content/train"
(x_train, y_train)=load_data(image_dir_path)
x_train = tf.cast(x_train, tf.float32)   ###########
x_train_norm = x_train/255.0   # 입력은 0~1 사이의 값으로 정규화

print("x_train shape: {}".format(x_train.shape))
print("y_train shape: {}".format(y_train.shape))

# test dataset
print('시험data: ')
image_dir_path = "/content/test"
(x_test, y_test)=load_data(image_dir_path)
x_test = tf.cast(x_test, tf.float32)   ###########
x_test_norm = x_test/255.0   # 입력은 0~1 사이의 값으로 정규화

print("x_test shape: {}".format(x_test.shape))
print("y_test shape: {}".format(y_test.shape))
# Out:
# 학습data:
# 데이터(x_train)의 이미지 개수는 300 입니다.
# x_train shape: (300, 28, 28, 3)
# y_train shape: (300,)
# 시험data:
# 데이터(x_train)의 이미지 개수는 300 입니다.
# x_test shape: (300, 28, 28, 3)
# y_test shape: (300,)

# %% [markdown]
# ## 1-5. 이미지 확인하기

# %%
plt.imshow(x_train_norm[100])
print('라벨: ', y_train[100], '[가위 : 0, 바위 : 1, 보 : 2]')
# Out:
# 라벨:  1 [가위 : 0, 바위 : 1, 보 : 2]

# %%
plt.imshow(x_test_norm[100])
print('라벨: ', y_test[100], '[가위 : 0, 바위 : 1, 보 : 2]')
# Out:
# 라벨:  1 [가위 : 0, 바위 : 1, 보 : 2]

# %% [markdown]
# # 2 딥러닝 네트워크 설계

# %% [markdown]
# ## 2-1. Sequential API로 모델 설계하기

# %% [markdown]
# > ■ 이미지 차원은 (28, 28, 3)<br>
# > ■ 1번째 Convolution layer의 feature수는 16, 2번째는 32<br>
# > ■ Dense layer의 출력 수는 label수에 같은 3에 고정<br>
# > ■ 총 7층의 CNN으로 구성 (전체적으로 숫자인식의 경우와 비슷하게 초기설정함)

# %%
n_channel_1=16
n_channel_2=32
n_dense=32

model=keras.models.Sequential()
model.add(keras.layers.Conv2D(n_channel_1, (3,3), activation='relu', input_shape=(28,28,3)))
model.add(keras.layers.MaxPool2D(2,2))
model.add(keras.layers.Conv2D(n_channel_2, (3,3), activation='relu'))
model.add(keras.layers.MaxPooling2D((2,2)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(n_dense, activation='relu'))
model.add(keras.layers.Dense(3, activation='softmax'))

model.summary()

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

keras.utils.plot_model(model, show_shapes=True, dpi = 70)
# Out:
# Model: "sequential_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_95 (Conv2D)          (None, 26, 26, 16)        448
#
#  max_pooling2d_90 (MaxPoolin  (None, 13, 13, 16)       0
#  g2D)
#
#  conv2d_96 (Conv2D)          (None, 11, 11, 32)        4640
#
#  max_pooling2d_91 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  flatten_41 (Flatten)        (None, 800)               0
#
#  dense_82 (Dense)            (None, 32)                25632
#
#  dense_83 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 30,819
# Trainable params: 30,819
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3 학습

# %% [markdown]
# ## 3-1. 모델 훈련시키기
# > ■ epoch는 추세확인을 위해 50으로 크게 시작했고, 39회에서  이미 accuracy 100%에 도달함을 확인함.

# %%
n_train_epoch=50

model.fit(x_train_norm, y_train, epochs=n_train_epoch)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 19ms/step - loss: 1.0502 - accuracy: 0.4733
# Epoch 2/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9002 - accuracy: 0.6500
# Epoch 3/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.7114 - accuracy: 0.7533
# Epoch 4/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.5422 - accuracy: 0.7800
# Epoch 5/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.4695 - accuracy: 0.7500
# Epoch 6/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.4368 - accuracy: 0.7667
# Epoch 7/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.3958 - accuracy: 0.7867
# Epoch 8/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3953 - accuracy: 0.7800
# Epoch 9/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.3333 - accuracy: 0.8767
# Epoch 10/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.3191 - accuracy: 0.8800
# Epoch 11/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.2842 - accuracy: 0.8933
# Epoch 12/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2547 - accuracy: 0.9233
# Epoch 13/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2217 - accuracy: 0.9267
# Epoch 14/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2057 - accuracy: 0.9200
# Epoch 15/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1769 - accuracy: 0.9600
# Epoch 16/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1695 - accuracy: 0.9300
# Epoch 17/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1660 - accuracy: 0.9333
# Epoch 18/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.2074 - accuracy: 0.8833
# Epoch 19/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1545 - accuracy: 0.9500
# Epoch 20/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1163 - accuracy: 0.9667
# Epoch 21/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1130 - accuracy: 0.9600
# Epoch 22/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0957 - accuracy: 0.9733
# Epoch 23/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0857 - accuracy: 0.9767
# Epoch 24/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0783 - accuracy: 0.9833
# Epoch 25/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0835 - accuracy: 0.9767
# Epoch 26/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0789 - accuracy: 0.9800
# Epoch 27/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0679 - accuracy: 0.9767
# Epoch 28/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0633 - accuracy: 0.9833
# Epoch 29/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0530 - accuracy: 0.9833
# Epoch 30/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0521 - accuracy: 0.9900
# Epoch 31/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0466 - accuracy: 0.9900
# Epoch 32/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0430 - accuracy: 0.9900
# Epoch 33/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0411 - accuracy: 0.9933
# Epoch 34/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0505 - accuracy: 0.9867
# Epoch 35/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0568 - accuracy: 0.9800
# Epoch 36/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0557 - accuracy: 0.9800
# Epoch 37/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0429 - accuracy: 0.9867
# Epoch 38/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0314 - accuracy: 0.9933
# Epoch 39/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 40/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0293 - accuracy: 0.9933
# Epoch 41/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0357 - accuracy: 0.9933
# Epoch 42/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0246 - accuracy: 0.9933
# Epoch 43/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 44/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 45/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 46/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 47/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 48/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 49/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 50/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0131 - accuracy: 1.0000

# %% [markdown]
# # 4 평가

# %% [markdown]
# ## 4-1. 1차 평가 결과
# > ■ accuracy 31%대 로 매우 저조함. <br>
# > ■ 매우 overfitting된 듯함. <br>
# > ■ 적절치 않은 하이퍼파라미터들을 사용했을 것으로 짐작됨.

# %%
test_loss, test_accuracy = model.evaluate(x_test_norm, y_test, verbose=2)
print("test_loss: {} ".format(test_loss))
print("test_accuracy: {}".format(test_accuracy))
# Out:
# 10/10 - 0s - loss: 3.7771 - accuracy: 0.3100 - 202ms/epoch - 20ms/step
# test_loss: 3.7770702838897705
# test_accuracy: 0.3100000023841858

# %% [markdown]
# # 5 개선

# %% [markdown]
# ## 5-1. 개선점

# %% [markdown]
# > ■ 기본 구조변경으로, 먼저 제3의 convolution layer을 추가하여 보다 추상적 정보를 풍부하게 하고.<br>
# > ■ 아울러, Dropout layer도 추가하여 overfitting에 대응함<br>
# > ■ 아래와 같이 하이퍼파라미터들을 변경해서 개선해 보기로 함.<br>
# > ■ epoch 수를 10로 조정 (overfitting대응) <br>
# > ■ 제3의 convolution layer를 추가함<br>
# > ■ 3번째 convolution layer의 n_channel_3=64로 정함<br>
# > ■ n_dense=64로 layer수가 증가함에 따라 크게 함 (32 -> 64)

# %%
# 모델 설계
n_channel_1=16
n_channel_2=32
n_channel_3=64
n_dense=64

model_new=keras.models.Sequential()
model_new.add(keras.layers.Conv2D(n_channel_1, (3,3), activation='relu', input_shape=(28,28,3)))
model_new.add(keras.layers.MaxPool2D(2,2))
model_new.add(keras.layers.Conv2D(n_channel_2, (3,3), activation='relu'))
model_new.add(keras.layers.MaxPooling2D((2,2)))
model_new.add(keras.layers.Conv2D(n_channel_3, (3,3), activation='relu'))
model_new.add(keras.layers.MaxPooling2D((2,2)))
model_new.add(keras.layers.Flatten())
model_new.add(keras.layers.Dropout(0.5))
model_new.add(keras.layers.Dense(n_dense, activation='relu'))
model_new.add(keras.layers.Dense(3, activation='softmax'))

model_new.summary()

model_new.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# 학습
n_train_epoch=10
model_new.fit(x_train_norm, y_train, epochs=n_train_epoch)

# 평가
test_loss, test_accuracy = model_new.evaluate(x_test_norm, y_test, verbose=2)
print("test_loss: {} ".format(test_loss))
print("test_accuracy: {}".format(test_accuracy))
# Out:
# Model: "sequential_44"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_100 (Conv2D)         (None, 26, 26, 16)        448
#
#  max_pooling2d_95 (MaxPoolin  (None, 13, 13, 16)       0
#  g2D)
#
#  conv2d_101 (Conv2D)         (None, 11, 11, 32)        4640
#
#  max_pooling2d_96 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  conv2d_102 (Conv2D)         (None, 3, 3, 64)          18496
#
#  max_pooling2d_97 (MaxPoolin  (None, 1, 1, 64)         0
#  g2D)
#
#  flatten_43 (Flatten)        (None, 64)                0
#
#  dropout_20 (Dropout)        (None, 64)                0
#
#  dense_86 (Dense)            (None, 64)                4160
#
#  dense_87 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 27,939
# Trainable params: 27,939
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 10/10 [==============================] - 2s 39ms/step - loss: 1.1008 - accuracy: 0.3433
# Epoch 2/10
# 10/10 [==============================] - 0s 33ms/step - loss: 1.0935 - accuracy: 0.3467
# Epoch 3/10
# 10/10 [==============================] - 0s 47ms/step - loss: 1.0892 - accuracy: 0.4233
# Epoch 4/10
# 10/10 [==============================] - 0s 27ms/step - loss: 1.0824 - accuracy: 0.4967
# Epoch 5/10
# 10/10 [==============================] - 0s 21ms/step - loss: 1.0678 - accuracy: 0.4200
# Epoch 6/10
# 10/10 [==============================] - 0s 20ms/step - loss: 1.0341 - accuracy: 0.4833
# Epoch 7/10
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9724 - accuracy: 0.5600
# Epoch 8/10
# 10/10 [==============================] - 0s 21ms/step - loss: 0.8692 - accuracy: 0.6467
# Epoch 9/10
# 10/10 [==============================] - 0s 21ms/step - loss: 0.7331 - accuracy: 0.6700
# Epoch 10/10
# 10/10 [==============================] - 0s 20ms/step - loss: 0.5877 - accuracy: 0.7167
# 10/10 - 0s - loss: 0.9097 - accuracy: 0.6000 - 228ms/epoch - 23ms/step
# test_loss: 0.9097450971603394
# test_accuracy: 0.6000000238418579

# %% [markdown]
# ## 5-2. 개선 결과
# <pre>■ 우선, CNN구조를 convolution layer를 추가하는 식으로 변경함에 따라 accuracy 60%대로 향상되었다.
# ■ convolution layer를 한개 더 추가 하므로, CNN이 보다 더 추상적인 정보 표현을 더 잘 한 거 같고,
#    overfitting을 대응하기 위하여, epoch수, Dropout layer추가한 부분이 도움이 되었던 거 같다.
# ■ 보다 체계적인 하이퍼파라미터 설정을 위하여, validation test를 했어야 했으나,
#    시간상, 못 한것이 아쉬웠었다.
